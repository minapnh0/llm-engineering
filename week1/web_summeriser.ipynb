# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

load_dotenv()
# Out:
# True

# %%
from typing import override


load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Welcome, and nice to meet you. I’m here to help with questions, explanations, writing, coding, planning, brainstorming, and lots more.\n\nA few quick ideas of what I can do:\n- Explain a topic or concept you’re curious about\n- Help write or edit something (emails, essays, stories)\n- Debug or explain code\n- Plan something (a trip, a project, a meal)\n- Practice a skill or language\n\nWhat would you like to start with today? If you tell me a bit about your interests, I can tailor suggestions.'

# %%
gwu = fetch_website_contents("https://www.gwu.edu/")
print(gwu)
# Out:
# The George Washington University
#
# Skip to main content
# Students
# Faculty & Staff
# Alumni
# Email
# GWeb
# Blackboard
# Directory
# Give
# Apply
# Main Bootstrap Navigation
# About
# Leadership
# Our Location
# Foggy Bottom Campus
# Mount Vernon Campus
# Virginia Science & Technology Campus
# Online & Virginia Academic Centers
# Admissions & Aid
# Undergraduate
# Graduate
# Academics
# Schools & Colleges
# Academic Calendar
# Research
# Revolutionary Impact
# GW Experience
# Campus Life
# Traditions
# Internships & Career Services
# Health & Wellness
# Arts & Culture
# Athletics
# About
# Leadership
# University Advancement
# General Counsel
# Health Affairs and School of Medicine & Health Sciences
# Provost
# Communications and Marketing
# Athletics
# Executive Vice President & Chief Financial Officer
# Senior Vice President and Chief of Staff
# The Office of Ethics, Compliance, and Risk
# Vice President and Dean of Enrollment Management and Student Success
# Vice President for Student Affairs and Dean of Students
# Our Location
# Foggy Bottom Campus
# Mount Vernon Campus
# Virginia Science & Technology Campus
# Online & Virginia Academic Centers
# Admissions & Aid
# Undergraduate
# Graduate
# Academics
# Schools & Colleges
# Academic Calendar
# Research
# Revolutionary Impact
# GW Experience
# Campus Life
# Traditions
# Internships & Career Services
# Health & Wellness
# Arts & Culture
# Athletics
# Homepage
# Steps away from
# World-class Opportunities
# At the George Washington University, countless new possibilities, new opportunities, and new discoveries
# are closer than ever.
# Find Your Program
# Visit
# Apply
# Video with audio descriptions
# Stories from Our Community
# Image
# Revolutionary Tales
# From overcoming personal challenges to launching bold new ventures and championing communities, GW students embody what it means to shape change on campus and beyond.
# Image
# Men's Swimming & Diving are 2026 A10 Champions
# GW's men's swimming & diving won it's sixth-consecutive Atlantic 10 Championship earlier this year. Raise High GW Revs!
# Make an Impact
# Image
# GW Research is Transforming Lives
# Every day, researc

# %%
system_prompt = """
You are a funny assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too."""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
messages_for(gwu)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a funny assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': "\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.The George Washington University\n\nSkip to main content\nStudents\nFaculty & Staff\nAlumni\nEmail\nGWeb\nBlackboard\nDirectory\nGive\nApply\nMain Bootstrap Navigation\nAbout\nLeadership\nOur Location\nFoggy Bottom Campus\nMount Vernon Campus\nVirginia Science & Technology Campus\nOnline & Virginia Academic Centers\nAdmissions & Aid\nUndergraduate\nGraduate\nAcademics\nSchools & Colleges\nAcademic Calendar\nResearch\nRevolutionary Impact\nGW Experience\nCampus Life\nTraditions\nInternships & Career Services\nHealth & Wellness\nArts & Culture\nAthletics\nAbout\nLeadership\nUniversity Advancement\nGeneral Counsel\nHealth Affairs and School of Medicine & Health Sciences\nProvost\nCommunications and Marketing\nAthletics\nExecutive Vice President & Chief Financial Officer\nSenior Vice President and Chief of Staff\nThe Office of Ethics, Compliance, and Risk\nVice President and Dean of Enrollment Management and Student Success\nVice President for Student Affairs and Dean of Students\nOur Location\nFoggy Bottom Campus\nMount Vernon Campus\nVirginia Science & Technology Campus\nOnline & Virginia Academic Centers\nAdmissions & Aid\nUndergraduate\nGraduate\nAcademics\nSchools & Colleges\nAcademic Calendar\nResearch\nRevolutionary Impact\nGW Experience\nCampus Life\nTraditions\nInternships & Career Services\nHealth & Wellness\nArts & Culture\nAthletics\nHomepage\nSteps away from\nWorld-class Opportunities\nAt the George Washington University, countless new possibilities, new opportunities, and new discoveries\nare closer than ever.\nFind Your Program\nVisit\nApply\nVideo with audio descriptions\nStories from Our Community\nImage\nRevolutionary Tales\nFrom overcoming personal challenges to launching bold new ventures and championing communities, GW students embody what it means to shape change on campus and beyond.\nImage\nMen's Swimming & Diving are 2026 A10 Champions\nGW's men's swimming & diving won it's sixth-consecutive Atlantic 10 Championship earlier this year. Raise High GW Revs!\nMake an Impact\nImage\nGW Research is Transforming Lives\nEvery day, researc"}]

# %%
def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://www.gwu.edu/")
# Out:
# "# The George Washington University: Where Revolutionary Dreams Meet Reality (and Swimming Trophies)\n\nWelcome to GWU, the place where students, faculty, and alumni mingle in a whirlwind of academics, athletics, and arts, all under the shadow of Washington’s most famous general’s name. Forget your usual college pitch — here, you get *revolutionary impact* (cue dramatic music) and a campus life that likely involves both launching start-ups and cheering on the six-time consecutive Atlantic 10 Champion men’s swimming & diving team. \n\nNews flash: The GW men’s swim team keeps conquering like it’s 1776 all over again. Meanwhile, research here promises to “transform lives,” which probably means more than just figuring out how to survive late-night study sessions and cafeteria pizza.\n\nIn short: Whether you're looking to find your program, visit, or apply, GWU offers a “world-class” experience packed with tradition, innovation, and enough student stories to fill a history book. Plus, they’ve got a campus at Foggy Bottom and other fancy locations — because why not?\n\nGrab your cap, your goggles, and your ambition — it’s revolutionary out here. 🎓🏊\u200d♂️✨"

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.gwu.edu/")
# Out:
# # The George Washington University website: TL;DR
#
# Welcome to GWU, where students apparently live just steps away from *world-class opportunities* (not actual Starbucks, but close enough). They have multiple campuses—because one campus is just too mainstream—and offer everything from undergrad to grad programs, online classes, and weird-sounding “Virginia Academic Centers.”
#
# Want to be a revolutionary? GWU’s got inspirational tales of students overcoming stuff and launching bold ventures, probably with coffee in hand. Also, their men's swimming & diving team is basically the Michael Phelps of the Atlantic 10 Conference, winning championships like it’s a hobby.
#
# Research at GWU is “transforming lives” daily, or so they say—presumably including making life better for people who can’t find the bookstore.
#
# In short: If you want a college with ambitious students, championship swimmers, endless programs, and a knack for sounding official, GWU is your spot.
